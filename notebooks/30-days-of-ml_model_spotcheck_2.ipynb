# %% [markdown]
# # 2nd round of model spot-check.
# We start with the models selected in 1st round a do some basic hyperparameter-tuning on each.
#
# My aim is to keep the best-performing model(s) for a final tuning.
#
# In this round I does not change the preprocessing used in the 1st round.

# %%
import numpy as np
import pandas as pd

# pipeline utilities
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# preprocessing
from sklearn.preprocessing import PowerTransformer, MinMaxScaler, OneHotEncoder # tuning: PolynomialFeatures
from sklearn.metrics import make_scorer, mean_squared_error

# tuning
from sklearn.model_selection import RandomizedSearchCV #, train_test_split
from scipy.stats import loguniform

# validation
from sklearn.model_selection import KFold, cross_val_score

# models
from sklearn.linear_model import ElasticNet, ElasticNetCV, BayesianRidge, ARDRegression
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
# Load data
df = pd.read_csv("../input/30-days-of-ml/train.csv", index_col=0)
df
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5  \
# id                                                        ...
# 1         B    B    B    C    B    B    A    E    C    N  ...  0.400361
# 2         B    B    A    A    B    D    A    F    A    O  ...  0.533087
# 3         A    A    A    C    B    D    A    D    A    F  ...  0.650609
# 4         B    B    A    C    B    D    A    E    C    K  ...  0.668980
# 6         A    A    A    C    B    D    A    E    A    N  ...  0.686964
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 499993    B    B    A    A    B    D    A    E    A    I  ...  0.769792
# 499996    A    B    A    C    B    B    A    E    E    F  ...  0.528056
# 499997    B    B    A    C    B    C    A    E    G    F  ...  0.688747
# 499998    A    B    A    C    B    B    A    E    E    I  ...  0.344404
# 499999    A    A    A    C    A    D    A    E    A    O  ...  0.565347
#
#            cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# id
# 1       0.160266  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401
# 2       0.558922  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975
# 3       0.375348  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474
# 4       0.239061  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150
# 6       0.420667  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849
# ...          ...       ...       ...       ...       ...       ...       ...
# 499993  0.450538  0.934360  1.005077  0.853726  0.422541  1.063463  0.697685
# 499996  0.508502  0.358247  0.257825  0.433525  0.301015  0.268447  0.577055
# 499997  0.372425  0.364936  0.383224  0.551825  0.661007  0.629606  0.714139
# 499998  0.424243  0.382028  0.468819  0.351036  0.288768  0.611169  0.380254
# 499999  0.328669  0.789165  0.960406  0.776019  0.734707  0.484392  0.639754
#
#           cont13    target
# id
# 1       0.869850  8.113634
# 2       0.465083  8.481233
# 3       0.763846  8.364351
# 4       0.280682  8.049253
# 6       0.250823  7.972260
# ...          ...       ...
# 499993  0.506404  7.945605
# 499996  0.823611  7.326118
# 499997  0.245732  8.706755
# 499998  0.332030  7.229569
# 499999  0.689317  8.631146
#
# [300000 rows x 25 columns]

# %%
# work on a random sample to speed-up process
df_sample = df.sample(50000, random_state=123)
X = df_sample.drop(['target'], axis=1)
y = df_sample['target']

# X = df.drop(['target'], axis=1)
# y = df['target']
print(X.shape)
print(y.shape)

# X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=123)
# print(X_train.shape)
# print(X_val.shape)
# print(y_train.shape)
# print(y_val.shape)
# Out:
# (50000, 24)
# (50000,)
# (37500, 24)
# (12500, 24)
# (37500,)
# (12500,)

# %%
# Select numerical features
numFeatures = X.select_dtypes(exclude=['object']).columns
# Select Categorical features
catFeatures = X.select_dtypes(include=['object']).columns
print(numFeatures)
print(catFeatures)
# Out:
# Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13'],
#       dtype='object')
# Index(['cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9'],
#       dtype='object')

# %%
# Pipeline for transforming categorical variables
catTransformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Pipeline for scaling numerical variables
numTransformer = Pipeline(steps=[
    ('scaler', MinMaxScaler()),
    ('power_transformer', PowerTransformer()),
])

# Create the preprocessing engine
preprocessor = ColumnTransformer(
    transformers=[
        ('numeric', numTransformer, numFeatures),
        ('categoric', catTransformer, catFeatures),
    ]
)

# %% [markdown]
# ## ElasticNet

# %%
model = ElasticNetCV(l1_ratio=[.1, .5, .7, .9, .15, .50, .75, .95, .99, 1], n_alphas=500, cv=5, random_state=123, verbose=0)

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)

estimator.fit(X, y)
m = estimator.named_steps['model']
print(f'alpha: {m.alpha_}')
print(f'l1_ratio: {m.l1_ratio_}')
# Out:
# alpha: 0.005706722247950045
# l1_ratio: 0.15

# %%
# test result parameters with ElasticNet and cross_val_score
model = ElasticNet(alpha=0.00570672, l1_ratio=0.15)
scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)
results = cross_val_score(estimator, X, y, cv=kf, scoring=scorer)
print(f"model score: {abs(results.mean()):.4f}")
# Out:
# model score: 0.5444

# %% [markdown]
# ## BayesianRidge

# %%
model = BayesianRidge(n_iter=1000)

param_distributions = {
    'model__alpha_1': loguniform(1e-8, 1e-4),
    'model__alpha_2': loguniform(1e-8, 1e-4),
    'model__lambda_1': loguniform(1e-8, 1e-4),
    'model__lambda_2': loguniform(1e-8, 1e-4),
}

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)

search_br = RandomizedSearchCV(
    estimator=estimator, 
    param_distributions=param_distributions,
    n_iter=20,
    scoring=scorer,
    cv=kf,
    random_state=123,
    verbose=2
)
search_br.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   5.5s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   5.4s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   5.2s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   3.9s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   3.4s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   3.6s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   4.1s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   3.4s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   3.2s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   2.9s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   3.3s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   3.6s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   3.5s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   3.8s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   3.2s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   3.1s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   3.1s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   5.2s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   3.8s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   3.0s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   5.1s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   3.7s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   4.3s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   4.1s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   3.5s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.4s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.9s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.9s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.9s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.4s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.6s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.8s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.7s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.9s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.6s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   3.7s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   3.8s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   3.5s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   3.9s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   3.7s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   3.4s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   3.7s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   3.7s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   4.1s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   3.7s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   3.8s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   3.7s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   4.4s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   5.4s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   3.7s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   2.8s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.0s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.2s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.3s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   2.9s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   3.2s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   3.7s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   7.3s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   4.7s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   3.7s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   2.7s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   2.8s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   4.0s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   3.3s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   5.7s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   3.2s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   3.1s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   4.5s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   4.3s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   5.3s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   5.0s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   4.7s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   3.5s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   2.8s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   3.1s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   2.7s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   2.9s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   3.6s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   3.3s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   3.5s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   3.1s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   2.8s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   2.9s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   3.2s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   2.8s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   2.8s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   2.8s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   3.1s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   3.8s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   3.0s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   4.9s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   3.0s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   3.8s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   3.9s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   2.7s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   2.8s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   2.9s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   2.9s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   3.2s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   3.3s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('numeric',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('power_transformer',
#                                                                                                 PowerTransformer())]),
#                                                                                Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'co...
#                                         'model__alpha_2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000029392673940>,
#                                         'model__lambda_1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000029392673080>,
#                                         'model__lambda_2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000293926732B0>},
#                    random_state=123,
#                    scoring=make_scorer(mean_squared_error, greater_is_better=False),
#                    verbose=2)

# %%
print("Best params")
print(search_br.best_params_)
print("\nScore")
print(f'{search_br.best_score_:.4f}')
# Out:
# Best params
# {'model__alpha_1': 7.758424358283755e-06, 'model__alpha_2': 1.9581035528392234e-07, 'model__lambda_1': 2.7999780223990073e-07, 'model__lambda_2': 8.185645330667258e-08}
#
# Score
# -0.5445

# %% [markdown]
# ## ARDRegression

# %%
model = ARDRegression(n_iter=1000)

param_distributions = {
    'model__alpha_1': loguniform(1e-8, 1e-4),
    'model__alpha_2': loguniform(1e-8, 1e-4),
    'model__lambda_1': loguniform(1e-8, 1e-4),
    'model__lambda_2': loguniform(1e-8, 1e-4),
}

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)

search_ardr = RandomizedSearchCV(
    estimator=estimator, 
    param_distributions=param_distributions,
    n_iter=20,
    scoring=scorer,
    cv=kf,
    random_state=123,
    verbose=2
)
search_ardr.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   4.8s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   7.1s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   6.4s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   5.2s
# [CV] END model__alpha_1=6.107686573608479e-06, model__alpha_2=1.39494581986112e-07, model__lambda_1=8.079896808319466e-08, model__lambda_2=1.6042020845182473e-06; total time=   5.4s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   4.2s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   6.4s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   5.7s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   6.2s
# [CV] END model__alpha_1=7.5487645402050296e-06, model__alpha_2=4.925222337791056e-07, model__lambda_1=8.376388146302439e-05, model__lambda_2=5.48679778118163e-06; total time=   4.6s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   7.0s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   6.5s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   5.5s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   6.1s
# [CV] END model__alpha_1=8.389336334792567e-07, model__alpha_2=3.7022869206988384e-07, model__lambda_1=2.3589137648150617e-07, model__lambda_2=8.245155098953613e-06; total time=   5.0s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   3.8s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   3.5s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   4.6s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   6.4s
# [CV] END model__alpha_1=5.679223741740074e-07, model__alpha_2=1.7326529663635616e-08, model__lambda_1=3.910002376153658e-07, model__lambda_2=8.953268791955232e-06; total time=   5.9s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   5.9s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   4.5s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   4.4s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   4.3s
# [CV] END model__alpha_1=5.3699089471963623e-08, model__alpha_2=5.0327693186635085e-08, model__lambda_1=1.3372281038573075e-06, model__lambda_2=1.340634367310211e-06; total time=   3.6s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.6s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.7s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.7s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   4.1s
# [CV] END model__alpha_1=3.4482904089131405e-06, model__alpha_2=2.498775138601464e-05, model__lambda_1=7.903533518289979e-06, model__lambda_2=2.7803152557785e-06; total time=   3.6s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.5s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.7s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.6s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   4.1s
# [CV] END model__alpha_1=7.758424358283755e-06, model__alpha_2=1.9581035528392234e-07, model__lambda_1=2.7999780223990073e-07, model__lambda_2=8.185645330667258e-08; total time=   3.9s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   3.6s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   5.1s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   5.3s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   4.8s
# [CV] END model__alpha_1=1.4957402671706665e-07, model__alpha_2=3.341215561348893e-06, model__lambda_1=2.3357145158910424e-08, model__lambda_2=5.430060779219497e-07; total time=   3.9s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   3.4s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   3.9s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   4.1s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   4.5s
# [CV] END model__alpha_1=5.289943741212551e-07, model__alpha_2=9.434967110751788e-07, model__lambda_1=5.050346330980688e-07, model__lambda_2=1.774372883716282e-07; total time=   3.5s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   3.4s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   4.0s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   4.0s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   4.3s
# [CV] END model__alpha_1=5.074639876783334e-07, model__alpha_2=3.745904080926281e-05, model__lambda_1=5.979158591419446e-05, model__lambda_2=1.0170603027497467e-06; total time=   3.6s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.5s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.8s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.8s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.9s
# [CV] END model__alpha_1=3.1319282717196e-06, model__alpha_2=2.9005047452739394e-08, model__lambda_1=1.858411684138563e-07, model__lambda_2=4.5635713798208254e-07; total time=   3.6s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   3.7s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   4.4s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   4.8s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   6.7s
# [CV] END model__alpha_1=2.919017048795455e-05, model__alpha_2=1.004202877716945e-07, model__lambda_1=8.553366021440324e-07, model__lambda_2=8.754657140659068e-05; total time=   7.1s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   4.4s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   4.7s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   6.0s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   5.0s
# [CV] END model__alpha_1=1.1965765212602297e-06, model__alpha_2=2.828642765376528e-06, model__lambda_1=3.03748865107569e-08, model__lambda_2=2.020055036708133e-05; total time=   4.7s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   3.7s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   3.8s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   4.2s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   5.4s
# [CV] END model__alpha_1=2.5836906504723756e-06, model__alpha_2=1.514509583721821e-06, model__lambda_1=2.3499322154972454e-07, model__lambda_2=1.6462021179757337e-07; total time=   4.2s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   4.6s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   5.2s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   4.9s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   4.6s
# [CV] END model__alpha_1=4.656813487239957e-07, model__alpha_2=5.311327280336982e-06, model__lambda_1=3.175611508579144e-05, model__lambda_2=1.1007516621231439e-06; total time=   4.0s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   3.9s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   3.6s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   4.5s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   5.2s
# [CV] END model__alpha_1=4.756145497401284e-06, model__alpha_2=2.2067148127117075e-06, model__lambda_1=3.1594683442464014e-06, model__lambda_2=4.99753913788935e-06; total time=   4.5s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   4.3s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   3.8s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   4.1s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   3.8s
# [CV] END model__alpha_1=2.340829330353506e-05, model__alpha_2=2.151691247778114e-08, model__lambda_1=1.1343089682264827e-05, model__lambda_2=9.43334022635702e-08; total time=   3.7s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   3.7s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   5.2s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   6.1s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   6.0s
# [CV] END model__alpha_1=5.982625838323249e-08, model__alpha_2=1.9490717640641528e-06, model__lambda_1=2.4146270773370442e-08, model__lambda_2=3.477821637156514e-05; total time=   5.3s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   3.8s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   3.7s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   6.5s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   4.7s
# [CV] END model__alpha_1=3.2284635552572538e-06, model__alpha_2=7.828263448438212e-06, model__lambda_1=1.1601571656744773e-08, model__lambda_2=2.3863136077647584e-06; total time=   4.2s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   4.2s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   3.4s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   4.5s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   4.7s
# [CV] END model__alpha_1=1.68709978305542e-06, model__alpha_2=4.323530993392179e-08, model__lambda_1=4.095265478887797e-08, model__lambda_2=6.0550553172016365e-06; total time=   4.5s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('numeric',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('power_transformer',
#                                                                                                 PowerTransformer())]),
#                                                                                Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'co...
#                                         'model__alpha_2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000293927F4630>,
#                                         'model__lambda_1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000293927F4828>,
#                                         'model__lambda_2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000293927F4A20>},
#                    random_state=123,
#                    scoring=make_scorer(mean_squared_error, greater_is_better=False),
#                    verbose=2)

# %%
print("Best params")
print(search_ardr.best_params_)
print("\nScore")
print(f'{search_ardr.best_score_:.4f}')
# Out:
# Best params
# {'model__alpha_1': 5.982625838323249e-08, 'model__alpha_2': 1.9490717640641528e-06, 'model__lambda_1': 2.4146270773370442e-08, 'model__lambda_2': 3.477821637156514e-05}
#
# Score
# -0.5447

# %% [markdown]
# ## Support Vector Regressor with linear kernel

# %%
model = LinearSVR(dual=False, loss='squared_epsilon_insensitive', random_state=123)

param_distributions = {
    'model__epsilon': [0, 0.01, 0.1, 0.5, 1, 2],
    'model__C': [1, 10, 100, 1000, 10000],
}

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)

search_lsvr = RandomizedSearchCV(
    estimator=estimator, 
    param_distributions=param_distributions,
    n_iter=20,
    scoring=scorer,
    cv=kf,
    random_state=123,
    verbose=2
)
search_lsvr.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END ...................model__C=10, model__epsilon=0.01; total time=   3.4s
# [CV] END ...................model__C=10, model__epsilon=0.01; total time=   2.7s
# [CV] END ...................model__C=10, model__epsilon=0.01; total time=   3.0s
# [CV] END ...................model__C=10, model__epsilon=0.01; total time=   2.7s
# [CV] END ...................model__C=10, model__epsilon=0.01; total time=   2.6s
# [CV] END ...................model__C=10000, model__epsilon=2; total time=   2.5s
# [CV] END ...................model__C=10000, model__epsilon=2; total time=   2.4s
# [CV] END ...................model__C=10000, model__epsilon=2; total time=   2.5s
# [CV] END ...................model__C=10000, model__epsilon=2; total time=   2.4s
# [CV] END ...................model__C=10000, model__epsilon=2; total time=   3.0s
# [CV] END .......................model__C=1, model__epsilon=2; total time=   2.3s
# [CV] END .......................model__C=1, model__epsilon=2; total time=   2.6s
# [CV] END .......................model__C=1, model__epsilon=2; total time=   3.0s
# [CV] END .......................model__C=1, model__epsilon=2; total time=   5.3s
# [CV] END .......................model__C=1, model__epsilon=2; total time=   3.4s
# [CV] END .................model__C=10000, model__epsilon=0.1; total time=   4.8s
# [CV] END .................model__C=10000, model__epsilon=0.1; total time=   4.7s
# [CV] END .................model__C=10000, model__epsilon=0.1; total time=   5.7s
# [CV] END .................model__C=10000, model__epsilon=0.1; total time=   5.6s
# [CV] END .................model__C=10000, model__epsilon=0.1; total time=   5.0s
# [CV] END ....................model__C=10, model__epsilon=0.1; total time=   3.6s
# [CV] END ....................model__C=10, model__epsilon=0.1; total time=   3.0s
# [CV] END ....................model__C=10, model__epsilon=0.1; total time=   2.5s
# [CV] END ....................model__C=10, model__epsilon=0.1; total time=   2.9s
# [CV] END ....................model__C=10, model__epsilon=0.1; total time=   2.5s
# [CV] END .................model__C=10000, model__epsilon=0.5; total time=   2.6s
# [CV] END .................model__C=10000, model__epsilon=0.5; total time=   2.4s
# [CV] END .................model__C=10000, model__epsilon=0.5; total time=   3.0s
# [CV] END .................model__C=10000, model__epsilon=0.5; total time=   5.4s
# [CV] END .................model__C=10000, model__epsilon=0.5; total time=   3.0s
# [CV] END .....................model__C=100, model__epsilon=0; total time=   3.7s
# [CV] END .....................model__C=100, model__epsilon=0; total time=   7.4s
# [CV] END .....................model__C=100, model__epsilon=0; total time=   5.2s
# [CV] END .....................model__C=100, model__epsilon=0; total time=   3.3s
# [CV] END .....................model__C=100, model__epsilon=0; total time=   3.3s
# [CV] END ..................model__C=1000, model__epsilon=0.5; total time=   3.7s
# [CV] END ..................model__C=1000, model__epsilon=0.5; total time=   3.2s
# [CV] END ..................model__C=1000, model__epsilon=0.5; total time=   2.3s
# [CV] END ..................model__C=1000, model__epsilon=0.5; total time=   3.1s
# [CV] END ..................model__C=1000, model__epsilon=0.5; total time=   2.2s
# [CV] END ......................model__C=10, model__epsilon=2; total time=   2.1s
# [CV] END ......................model__C=10, model__epsilon=2; total time=   2.1s
# [CV] END ......................model__C=10, model__epsilon=2; total time=   2.5s
# [CV] END ......................model__C=10, model__epsilon=2; total time=   2.3s
# [CV] END ......................model__C=10, model__epsilon=2; total time=   2.2s
# [CV] END ....................model__C=1000, model__epsilon=2; total time=   1.9s
# [CV] END ....................model__C=1000, model__epsilon=2; total time=   3.0s
# [CV] END ....................model__C=1000, model__epsilon=2; total time=   2.4s
# [CV] END ....................model__C=1000, model__epsilon=2; total time=   2.4s
# [CV] END ....................model__C=1000, model__epsilon=2; total time=   2.0s
# [CV] END ....................model__C=1000, model__epsilon=0; total time=   2.6s
# [CV] END ....................model__C=1000, model__epsilon=0; total time=   2.7s
# [CV] END ....................model__C=1000, model__epsilon=0; total time=   3.7s
# [CV] END ....................model__C=1000, model__epsilon=0; total time=   3.1s
# [CV] END ....................model__C=1000, model__epsilon=0; total time=   3.7s
# [CV] END .......................model__C=1, model__epsilon=1; total time=   2.8s
# [CV] END .......................model__C=1, model__epsilon=1; total time=   3.5s
# [CV] END .......................model__C=1, model__epsilon=1; total time=   3.7s
# [CV] END .......................model__C=1, model__epsilon=1; total time=   3.4s
# [CV] END .......................model__C=1, model__epsilon=1; total time=   2.5s
# [CV] END .....................model__C=1, model__epsilon=0.5; total time=   2.4s
# [CV] END .....................model__C=1, model__epsilon=0.5; total time=   2.6s
# [CV] END .....................model__C=1, model__epsilon=0.5; total time=   2.3s
# [CV] END .....................model__C=1, model__epsilon=0.5; total time=   2.8s
# [CV] END .....................model__C=1, model__epsilon=0.5; total time=   2.4s
# [CV] END ...................model__C=10000, model__epsilon=0; total time=   2.4s
# [CV] END ...................model__C=10000, model__epsilon=0; total time=   4.1s
# [CV] END ...................model__C=10000, model__epsilon=0; total time=   3.5s
# [CV] END ...................model__C=10000, model__epsilon=0; total time=   3.0s
# [CV] END ...................model__C=10000, model__epsilon=0; total time=   3.2s
# [CV] END .....................model__C=100, model__epsilon=1; total time=   2.6s
# [CV] END .....................model__C=100, model__epsilon=1; total time=   3.8s
# [CV] END .....................model__C=100, model__epsilon=1; total time=   3.3s
# [CV] END .....................model__C=100, model__epsilon=1; total time=   3.0s
# [CV] END .....................model__C=100, model__epsilon=1; total time=   3.0s
# [CV] END ...................model__C=100, model__epsilon=0.1; total time=   3.0s
# [CV] END ...................model__C=100, model__epsilon=0.1; total time=   3.3s
# [CV] END ...................model__C=100, model__epsilon=0.1; total time=   3.0s
# [CV] END ...................model__C=100, model__epsilon=0.1; total time=   3.0s
# [CV] END ...................model__C=100, model__epsilon=0.1; total time=   2.8s
# [CV] END ..................model__C=1000, model__epsilon=0.1; total time=   3.2s
# [CV] END ..................model__C=1000, model__epsilon=0.1; total time=   2.6s
# [CV] END ..................model__C=1000, model__epsilon=0.1; total time=   2.9s
# [CV] END ..................model__C=1000, model__epsilon=0.1; total time=   2.9s
# [CV] END ..................model__C=1000, model__epsilon=0.1; total time=   2.9s
# [CV] END ....................model__C=10, model__epsilon=0.5; total time=   2.6s
# [CV] END ....................model__C=10, model__epsilon=0.5; total time=   2.8s
# [CV] END ....................model__C=10, model__epsilon=0.5; total time=   3.0s
# [CV] END ....................model__C=10, model__epsilon=0.5; total time=   2.9s
# [CV] END ....................model__C=10, model__epsilon=0.5; total time=   2.7s
# [CV] END ...................model__C=100, model__epsilon=0.5; total time=   3.2s
# [CV] END ...................model__C=100, model__epsilon=0.5; total time=   2.9s
# [CV] END ...................model__C=100, model__epsilon=0.5; total time=   3.8s
# [CV] END ...................model__C=100, model__epsilon=0.5; total time=   3.4s
# [CV] END ...................model__C=100, model__epsilon=0.5; total time=   2.6s
# [CV] END ................model__C=10000, model__epsilon=0.01; total time=   3.2s
# [CV] END ................model__C=10000, model__epsilon=0.01; total time=   3.0s
# [CV] END ................model__C=10000, model__epsilon=0.01; total time=   2.4s
# [CV] END ................model__C=10000, model__epsilon=0.01; total time=   2.6s
# [CV] END ................model__C=10000, model__epsilon=0.01; total time=   2.3s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('numeric',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('power_transformer',
#                                                                                                 PowerTransformer())]),
#                                                                                Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'co...
#                                                                                Index(['cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9'],
#       dtype='object'))])),
#                                              ('model',
#                                               LinearSVR(dual=False,
#                                                         loss='squared_epsilon_insensitive',
#                                                         random_state=123))]),
#                    n_iter=20,
#                    param_distributions={'model__C': [1, 10, 100, 1000, 10000],
#                                         'model__epsilon': [0, 0.01, 0.1, 0.5, 1,
#                                                            2]},
#                    random_state=123,
#                    scoring=make_scorer(mean_squared_error, greater_is_better=False),
#                    verbose=2)

# %%
print("Best params")
print(search_lsvr.best_params_)
print("\nScore")
print(f'{search_lsvr.best_score_:.4f}')
# Out:
# Best params
# {'model__epsilon': 0, 'model__C': 100}
#
# Score
# -0.5449

# %% [markdown]
# ## RandomForestRegressor

# %%
model = RandomForestRegressor(random_state=123)

param_distributions = {
    'model__n_estimators': [100, 300, 500],
    'model__max_depth': [3, 5, 10, 15],
    'model__min_samples_leaf': [0.001, 0.01, 0.1],
    'model__max_features': ['sqrt', 'log2'],
}

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)

search_rfr = RandomizedSearchCV(
    estimator=estimator, 
    param_distributions=param_distributions,
    n_iter=20,
    scoring=scorer,
    cv=kf,
    random_state=123,
    verbose=2
)
search_rfr.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  20.9s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  23.0s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  30.5s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  20.5s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  20.5s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  32.5s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  37.6s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  29.5s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  28.1s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  27.4s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  21.7s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  22.1s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  24.2s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  29.4s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  27.1s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time= 1.4min
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time= 1.3min
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  50.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  49.0s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  49.3s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  48.9s
# [CV] END model__max_depth=5, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  48.7s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  26.0s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  26.1s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  24.8s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  24.3s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  24.4s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.6s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.6s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.9s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  13.0s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.8s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  46.9s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  43.1s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  43.0s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  43.2s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  43.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time=  36.9s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time=  37.8s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time=  37.6s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time=  37.5s
# [CV] END model__max_depth=5, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=500; total time=  37.2s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  19.4s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  19.8s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  20.5s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  19.6s
# [CV] END model__max_depth=15, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100; total time=  19.7s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=   6.9s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=   6.7s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=   6.7s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=   7.1s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100; total time=   6.7s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  25.5s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  25.1s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  26.7s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  27.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500; total time=  25.1s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  46.7s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  47.0s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  47.2s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  47.5s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  48.9s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300; total time=  45.2s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300; total time=  37.2s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300; total time=  36.4s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300; total time=  36.3s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300; total time=  36.4s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.3s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.9s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.9s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.6s
# [CV] END model__max_depth=15, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  12.6s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  19.3s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  19.1s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  22.4s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  20.2s
# [CV] END model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300; total time=  19.4s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  18.4s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  16.9s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  15.6s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  15.7s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=300; total time=  15.5s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=100; total time=   6.7s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=100; total time=   6.8s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=100; total time=   9.7s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=100; total time=   8.2s
# [CV] END model__max_depth=10, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=100; total time=   7.9s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  48.5s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  46.6s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  45.8s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  46.9s
# [CV] END model__max_depth=10, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  46.9s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  24.6s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  24.8s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  24.8s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  24.8s
# [CV] END model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500; total time=  24.7s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('numeric',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('power_transformer',
#                                                                                                 PowerTransformer())]),
#                                                                                Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'co...
#        'cat9'],
#       dtype='object'))])),
#                                              ('model',
#                                               RandomForestRegressor(random_state=123))]),
#                    n_iter=20,
#                    param_distributions={'model__max_depth': [3, 5, 10, 15],
#                                         'model__max_features': ['sqrt', 'log2'],
#                                         'model__min_samples_leaf': [0.001, 0.01,
#                                                                     0.1],
#                                         'model__n_estimators': [100, 300, 500]},
#                    random_state=123,
#                    scoring=make_scorer(mean_squared_error, greater_is_better=False),
#                    verbose=2)

# %%
print("Best params")
print(search_rfr.best_params_)
print("\nScore")
print(f'{search_rfr.best_score_:.4f}')
# Out:
# Best params
# {'model__n_estimators': 100, 'model__min_samples_leaf': 0.001, 'model__max_features': 'sqrt', 'model__max_depth': 15}
#
# Score
# -0.5396

# %% [markdown]
# ## GradientBoostingRegressor

# %%
model = GradientBoostingRegressor(random_state=123)

param_distributions = {
    'model__loss': ['ls', 'lad', 'huber', 'quantile'],
    'model__learning_rate': [0.01, 0.1],
    'model__n_estimators': [100, 300, 500],
    'model__subsample': [0.5, 0.8, 1],
    'model__max_depth': [3, 7, 12],
    'model__min_samples_leaf': [0.001, 0.01, 0.1],
    'model__max_features': ['sqrt', 'log2'],
}

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)

search_gbr = RandomizedSearchCV(
    estimator=estimator, 
    param_distributions=param_distributions,
    n_iter=20,
    scoring=scorer,
    cv=kf,
    random_state=123,
    verbose=2
)
search_gbr.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.8; total time=  35.8s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.8; total time=  33.4s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.8; total time=  32.6s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.8; total time=  37.5s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.8; total time=  42.1s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=0.8; total time=  30.3s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=0.8; total time=  34.2s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=0.8; total time=  32.9s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=0.8; total time=  28.8s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=0.8; total time=  28.1s
# [CV] END model__learning_rate=0.1, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500, model__subsample=0.5; total time=  35.9s
# [CV] END model__learning_rate=0.1, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500, model__subsample=0.5; total time=  35.6s
# [CV] END model__learning_rate=0.1, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500, model__subsample=0.5; total time=  33.6s
# [CV] END model__learning_rate=0.1, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500, model__subsample=0.5; total time=  37.6s
# [CV] END model__learning_rate=0.1, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.1, model__n_estimators=500, model__subsample=0.5; total time=  37.5s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=0.8; total time=  13.9s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=0.8; total time=  13.4s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=0.8; total time=  15.6s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=0.8; total time=  14.7s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=0.8; total time=  17.4s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  39.8s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  40.2s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  37.6s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  43.0s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  44.2s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.5; total time=  20.8s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.5; total time=  20.5s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.5; total time=  21.5s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.5; total time=  19.8s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.5; total time=  19.1s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  58.2s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  56.5s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time= 1.0min
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time= 1.5min
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=3, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  56.5s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  50.4s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  51.8s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time= 1.0min
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  53.4s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  56.9s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=1; total time= 2.1min
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=1; total time= 2.0min
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=1; total time= 1.7min
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=1; total time= 1.9min
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=1; total time= 1.8min
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  37.3s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  42.8s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  35.0s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  41.4s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=300, model__subsample=1; total time=  35.3s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.5; total time=  52.6s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.5; total time=  53.6s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.5; total time=  58.4s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.5; total time=  55.5s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=300, model__subsample=0.5; total time=  58.9s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=100, model__subsample=1; total time=  14.6s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=100, model__subsample=1; total time=  15.1s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=100, model__subsample=1; total time=  13.8s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=100, model__subsample=1; total time=  12.4s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=100, model__subsample=1; total time=  14.9s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  33.4s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  29.8s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  25.6s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  25.3s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.5; total time=  26.1s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  24.7s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  24.2s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  22.0s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  21.0s
# [CV] END model__learning_rate=0.01, model__loss=quantile, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  20.8s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  32.2s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  32.2s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  34.3s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  29.5s
# [CV] END model__learning_rate=0.1, model__loss=huber, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  29.3s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  23.8s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  24.9s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  20.2s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  20.2s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  21.8s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  40.6s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  47.2s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  41.8s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  41.6s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=12, model__max_features=log2, model__min_samples_leaf=0.001, model__n_estimators=100, model__subsample=1; total time=  41.5s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  34.4s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  39.3s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  40.1s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  43.7s
# [CV] END model__learning_rate=0.01, model__loss=ls, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.01, model__n_estimators=500, model__subsample=0.8; total time=  36.2s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300, model__subsample=1; total time=  31.8s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300, model__subsample=1; total time=  28.6s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300, model__subsample=1; total time=  28.3s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300, model__subsample=1; total time=  30.2s
# [CV] END model__learning_rate=0.1, model__loss=lad, model__max_depth=3, model__max_features=log2, model__min_samples_leaf=0.1, model__n_estimators=300, model__subsample=1; total time=  27.4s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  22.3s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  27.2s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  26.7s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  25.4s
# [CV] END model__learning_rate=0.01, model__loss=lad, model__max_depth=7, model__max_features=sqrt, model__min_samples_leaf=0.01, model__n_estimators=100, model__subsample=0.8; total time=  24.3s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('numeric',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('power_transformer',
#                                                                                                 PowerTransformer())]),
#                                                                                Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'co...
#                    param_distributions={'model__learning_rate': [0.01, 0.1],
#                                         'model__loss': ['ls', 'lad', 'huber',
#                                                         'quantile'],
#                                         'model__max_depth': [3, 7, 12],
#                                         'model__max_features': ['sqrt', 'log2'],
#                                         'model__min_samples_leaf': [0.001, 0.01,
#                                                                     0.1],
#                                         'model__n_estimators': [100, 300, 500],
#                                         'model__subsample': [0.5, 0.8, 1]},
#                    random_state=123,
#                    scoring=make_scorer(mean_squared_error, greater_is_better=False),
#                    verbose=2)

# %%
print("Best params")
print(search_gbr.best_params_)
print("\nScore")
print(f'{search_gbr.best_score_:.4f}')
# Out:
# Best params
# {'model__subsample': 1, 'model__n_estimators': 300, 'model__min_samples_leaf': 0.001, 'model__max_features': 'log2', 'model__max_depth': 3, 'model__loss': 'huber', 'model__learning_rate': 0.1}
#
# Score
# -0.5327

# %% [markdown]
# ## XGBRegressor

# %%
model = XGBRegressor(random_state=123)

param_distributions = {
    'model__n_estimators': [100, 300, 500],
    'model__max_depth': [3, 7, 12],
    'model__learning_rate': [0.01, 0.1, 0.5, 0.9],    
    'model__subsample': [0.3, 0.5, 0.9],
    'model__colsample_bytree': [0.1, 0.3, 0.6, 1],
    'model__booster': ['gbtree'],
}

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)

search_xgbr = RandomizedSearchCV(
    estimator=estimator, 
    param_distributions=param_distributions,
    n_iter=20,
    scoring=scorer,
    cv=kf,
    random_state=123,
    verbose=2
)
search_xgbr.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300, model__subsample=0.5; total time=  25.7s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300, model__subsample=0.5; total time=  25.1s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300, model__subsample=0.5; total time=  23.2s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300, model__subsample=0.5; total time=  23.6s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300, model__subsample=0.5; total time=  23.0s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=500, model__subsample=0.5; total time= 3.6min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=500, model__subsample=0.5; total time= 3.7min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=500, model__subsample=0.5; total time= 3.6min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=500, model__subsample=0.5; total time= 3.3min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=500, model__subsample=0.5; total time= 3.0min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=  24.0s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=  23.9s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=  23.8s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=  23.6s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=  24.2s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.3, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.5; total time=  14.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.3, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.5; total time=  14.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.3, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.5; total time=  14.4s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.3, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.5; total time=  14.2s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.3, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=100, model__subsample=0.5; total time=  14.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=500, model__subsample=0.5; total time= 2.7min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=500, model__subsample=0.5; total time= 2.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=500, model__subsample=0.5; total time= 2.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=500, model__subsample=0.5; total time= 2.9min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=7, model__n_estimators=500, model__subsample=0.5; total time= 2.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3; total time=  39.1s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3; total time=  40.8s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3; total time=  39.0s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3; total time=  37.4s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3; total time=  38.4s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time= 2.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time= 2.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time= 2.3min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time= 2.3min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time= 2.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  28.7s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  29.6s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  29.6s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  29.2s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  29.1s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=   6.2s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=   7.4s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=   6.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=   6.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100, model__subsample=0.9; total time=   6.8s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.9; total time= 2.1min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.9; total time= 1.8min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.9; total time= 1.8min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.9; total time= 1.9min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.9; total time= 1.9min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  39.7s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  36.9s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  36.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  33.3s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.1, model__max_depth=7, model__n_estimators=500, model__subsample=0.3; total time=  33.0s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=300, model__subsample=0.9; total time= 2.0min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=300, model__subsample=0.9; total time= 2.0min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=300, model__subsample=0.9; total time= 2.0min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=300, model__subsample=0.9; total time= 2.0min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=12, model__n_estimators=300, model__subsample=0.9; total time= 2.0min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time=  45.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time=  42.8s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time=  43.9s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time=  46.0s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.01, model__max_depth=12, model__n_estimators=500, model__subsample=0.3; total time=127.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=3, model__n_estimators=100, model__subsample=0.3; total time=  54.7s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=3, model__n_estimators=100, model__subsample=0.3; total time=  16.7s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=3, model__n_estimators=100, model__subsample=0.3; total time=  12.0s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=3, model__n_estimators=100, model__subsample=0.3; total time=  11.4s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=3, model__n_estimators=100, model__subsample=0.3; total time=  12.1s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 1.9min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 2.8min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 2.2min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 2.3min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 2.3min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=3, model__n_estimators=100, model__subsample=0.5; total time=  18.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=3, model__n_estimators=100, model__subsample=0.5; total time=  19.0s
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=3, model__n_estimators=100, model__subsample=0.5; total time=  19.7s
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=3, model__n_estimators=100, model__subsample=0.5; total time=  17.9s
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=3, model__n_estimators=100, model__subsample=0.5; total time=  17.5s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.9; total time=  14.4s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.9; total time=  12.8s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.9; total time=  14.6s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.9; total time=  14.2s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.9; total time=  13.3s
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 2.7min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 3.1min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 3.3min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 3.1min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.9, model__max_depth=12, model__n_estimators=300, model__subsample=0.5; total time= 3.2min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time= 2.5min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time= 2.9min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time= 3.6min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time= 2.3min
# [CV] END model__booster=gbtree, model__colsample_bytree=1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time= 2.4min
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time=  38.9s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time=  36.1s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time=  32.8s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time=  34.6s
# [CV] END model__booster=gbtree, model__colsample_bytree=0.1, model__learning_rate=0.5, model__max_depth=12, model__n_estimators=300, model__subsample=0.3; total time=  39.5s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('numeric',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 MinMaxScaler()),
#                                                                                                ('power_transformer',
#                                                                                                 PowerTransformer())]),
#                                                                                Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'co...
#                                                            verbosity=None))]),
#                    n_iter=20,
#                    param_distributions={'model__booster': ['gbtree'],
#                                         'model__colsample_bytree': [0.1, 0.3,
#                                                                     0.6, 1],
#                                         'model__learning_rate': [0.01, 0.1, 0.5,
#                                                                  0.9],
#                                         'model__max_depth': [3, 7, 12],
#                                         'model__n_estimators': [100, 300, 500],
#                                         'model__subsample': [0.3, 0.5, 0.9]},
#                    random_state=123,
#                    scoring=make_scorer(mean_squared_error, greater_is_better=False),
#                    verbose=2)

# %%
print("Best params")
print(search_xgbr.best_params_)
print("\nScore")
print(f'{search_xgbr.best_score_:.4f}')
# Out:
# Best params
# {'model__subsample': 0.3, 'model__n_estimators': 500, 'model__max_depth': 3, 'model__learning_rate': 0.1, 'model__colsample_bytree': 0.6, 'model__booster': 'gbtree'}
#
# Score
# -0.5307

# %% [markdown]
# |model                      | score
# |-----------------------    |--------
# |XGBRegressor               | 0.5307
# |GradientBoostingRegressor  | 0.5327
# |RandomForestRegressor      | 0.5396
# |ElasticNet                 | 0.5444
# |BayesianRidge              | 0.5445
# |ARDRegression              | 0.5447
# |LinearSVR                  | 0.5449

# %% [markdown]
# We keep XGBoost for further tuning.

# %% [markdown]
# ## Make submission using winner of this round: XGBRegressor

# %%
# load test data
test_df = pd.read_csv("../input/30-days-of-ml/test.csv", index_col=0)
# split dataset
X_train = df.drop(['target'], axis=1)
y_train = df['target']
X_test = test_df
# train model
model_params = {
    'subsample': 0.3, 
    'n_estimators': 500, 
    'max_depth': 3, 
    'learning_rate': 0.1, 
    'colsample_bytree': 0.6, 
    'booster': 'gbtree'
}
model = XGBRegressor(random_state=123, **model_params)
estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ]
)
estimator.fit(X_train, y_train)
# predict
y_pred = estimator.predict(X_test)
# save the predictions to a CSV file
output = pd.DataFrame({'Id': X_test.index,
                       'target': y_pred})
output.to_csv('submission.csv', index=False)
# Out:
# [19:20:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "model__booster", "model__colsample_bytree", "model__learning_rate", "model__max_depth", "model__n_estimators", "model__subsample" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31516/4834646.py in <module>
#      21     ]
#      22 )
# ---> 23 estimator.fit(X_train, y_train)
#      24 # predict
#      25 y_pred = estimator.predict(X_test)
#
# ~\.virtualenvs\Kaggle-axgtS9bO\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~\.virtualenvs\Kaggle-axgtS9bO\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     434         for k, arg in zip(sig.parameters, args):
#     435             kwargs[k] = arg
# --> 436         return f(**kwargs)
#     437
#     438     return inner_f
#
# ~\.virtualenvs\Kaggle-axgtS9bO\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     745             verbose_eval=verbose,
#     746             xgb_model=model,
# --> 747             callbacks=callbacks,
#     748         )
#     749
#
# ~\.virtualenvs\Kaggle-axgtS9bO\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     195                           evals_result=evals_result,
#     196                           maximize=maximize,
# --> 197                           early_stopping_rounds=early_stopping_rounds)
#     198     return bst
#     199
#
# ~\.virtualenvs\Kaggle-axgtS9bO\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# ~\.virtualenvs\Kaggle-axgtS9bO\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1499             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1500                                                     ctypes.c_int(iteration),
# -> 1501                                                     dtrain.handle))
#    1502         else:
#    1503             pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
