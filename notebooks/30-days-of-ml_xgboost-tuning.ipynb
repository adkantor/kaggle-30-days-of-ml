# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/30-days-of-ml/sample_submission.csv
# /kaggle/input/30-days-of-ml/train.csv
# /kaggle/input/30-days-of-ml/test.csv

# %%
# pipeline utilities
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# preprocessing
from sklearn.preprocessing import PowerTransformer, MinMaxScaler, OneHotEncoder, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.metrics import make_scorer, mean_squared_error

# tuning
from sklearn.model_selection import GridSearchCV

# validation
from sklearn.model_selection import KFold, train_test_split

# model
from xgboost import XGBRegressor

# %%
# Load data
df = pd.read_csv("../input/30-days-of-ml/train.csv", index_col=0)
df
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5  \
# id                                                        ...
# 1         B    B    B    C    B    B    A    E    C    N  ...  0.400361
# 2         B    B    A    A    B    D    A    F    A    O  ...  0.533087
# 3         A    A    A    C    B    D    A    D    A    F  ...  0.650609
# 4         B    B    A    C    B    D    A    E    C    K  ...  0.668980
# 6         A    A    A    C    B    D    A    E    A    N  ...  0.686964
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 499993    B    B    A    A    B    D    A    E    A    I  ...  0.769792
# 499996    A    B    A    C    B    B    A    E    E    F  ...  0.528056
# 499997    B    B    A    C    B    C    A    E    G    F  ...  0.688747
# 499998    A    B    A    C    B    B    A    E    E    I  ...  0.344404
# 499999    A    A    A    C    A    D    A    E    A    O  ...  0.565347
#
#            cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# id
# 1       0.160266  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401
# 2       0.558922  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975
# 3       0.375348  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474
# 4       0.239061  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150
# 6       0.420667  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849
# ...          ...       ...       ...       ...       ...       ...       ...
# 499993  0.450538  0.934360  1.005077  0.853726  0.422541  1.063463  0.697685
# 499996  0.508502  0.358247  0.257825  0.433525  0.301015  0.268447  0.577055
# 499997  0.372425  0.364936  0.383224  0.551825  0.661007  0.629606  0.714139
# 499998  0.424243  0.382028  0.468819  0.351036  0.288768  0.611169  0.380254
# 499999  0.328669  0.789165  0.960406  0.776019  0.734707  0.484392  0.639754
#
#           cont13    target
# id
# 1       0.869850  8.113634
# 2       0.465083  8.481233
# 3       0.763846  8.364351
# 4       0.280682  8.049253
# 6       0.250823  7.972260
# ...          ...       ...
# 499993  0.506404  7.945605
# 499996  0.823611  7.326118
# 499997  0.245732  8.706755
# 499998  0.332030  7.229569
# 499999  0.689317  8.631146
#
# [300000 rows x 25 columns]

# %%
# work on a random sample to speed-up process
# df_sample = df.sample(1000, random_state=123)
# X = df_sample.drop(['target'], axis=1)
# y = df_sample['target']

X = df.drop(['target'], axis=1)
y = df['target']
print(X.shape)
print(y.shape)
# Out:
# (300000, 24)
# (300000,)

# %%
# Select numerical features
numFeatures = X.select_dtypes(exclude=['object']).columns
# Select Categorical features
catFeatures = X.select_dtypes(include=['object']).columns
print(numFeatures)
print(catFeatures)
# Out:
# Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13'],
#       dtype='object')
# Index(['cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9'],
#       dtype='object')

# %%
# Pipeline for transforming categorical variables
catTransformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Pipeline for scaling numerical variables
numTransformer = Pipeline(steps=[
    ('scaler', MinMaxScaler()),
    ('power', PowerTransformer()),
])

# Create the preprocessing engine
preprocessor = ColumnTransformer(
    transformers=[
        ('numeric', numTransformer, numFeatures),
        ('categoric', catTransformer, catFeatures),
    ]
)

# %% [markdown]
# ## Find PCA's optimal component number
#
# 60 found to be optimal (with 5-fold cross-validation, using hyperparameters from previous round).

# %% [markdown]
# ## Fine-tune

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)
val_preprocessor = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('dimred', PCA(random_state=123)),
    ]
)

model = XGBRegressor(
    tree_method='gpu_hist',
    objective='reg:squarederror',
    random_state=123
)

param_grid = {
    'model__n_estimators': [500, 1000, 1500],
    'model__max_depth': [2, 3, 4],
    'model__learning_rate': [0.1],    
    'model__subsample': [0.3],
    'model__colsample_bytree': [0.6],
    'model__booster': ['gbtree', 'gblinear', 'dart']
}

scorer = make_scorer(score_func=mean_squared_error, greater_is_better=False)
kf = KFold(n_splits=5)

estimator = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('dimred', PCA(n_components=60, random_state=123)),
        ('model', model)
    ]
)

search_xgbr = GridSearchCV(
    estimator=estimator, 
    param_grid=param_grid,
    scoring=scorer,
    cv=kf,
    verbose=2
)
search_xgbr.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=  10.3s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.3s remaining:    0.0s
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=   8.1s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=   8.5s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=   8.0s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=   7.7s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total=   9.3s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total=   8.6s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total=   9.4s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total=   8.9s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total=   9.0s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=   9.9s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=   9.5s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=  10.8s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=  10.1s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=   9.8s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=   8.3s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=   8.1s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=   9.2s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=   8.5s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=   8.2s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total=   9.7s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total=   9.2s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total=   9.8s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total=   9.9s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total=   9.7s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=  10.7s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=  10.4s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=  11.4s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=  10.9s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=  10.7s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=   8.7s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=   8.2s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=   9.3s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=   8.8s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=   8.9s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total=  10.3s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total=  10.0s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total=  11.1s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total=  10.5s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total=  10.3s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=  12.0s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=  11.7s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=  12.4s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=  12.2s
# [CV] model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=gbtree, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=  12.0s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [17:30:29] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=  38.8s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [17:31:07] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=  38.1s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [17:31:47] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=  38.6s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [17:32:25] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=  38.9s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [17:33:04] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total=  40.1s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [17:33:44] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [17:34:53] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [17:36:04] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [17:37:14] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [17:38:24] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [17:39:34] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [17:41:15] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [17:42:57] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [17:44:39] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [17:46:20] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [17:48:01] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=  38.2s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [17:48:39] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=  38.2s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [17:49:18] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=  39.2s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [17:49:57] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=  38.7s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [17:50:36] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total=  38.7s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [17:51:14] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [17:52:25] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [17:53:35] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [17:54:46] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [17:55:56] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [17:57:07] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [17:58:48] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [18:00:30] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [18:02:12] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [18:03:53] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [18:05:35] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=  38.5s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [18:06:13] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=  38.3s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [18:06:52] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=  39.1s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [18:07:31] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=  38.7s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [18:08:10] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total=  38.8s
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [18:08:48] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [18:09:58] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [18:11:09] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [18:12:20] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [18:13:30] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 1.2min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [18:14:40] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [18:16:21] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [18:18:03] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [18:19:46] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [18:21:27] WARNING: ../src/learner.cc:573:
# Parameters: { "colsample_bytree", "max_depth", "subsample", "tree_method" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  model__booster=gblinear, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total= 1.7min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 6.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 6.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 6.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 6.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1000, model__subsample=0.3, total= 6.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=15.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=15.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=15.1min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=15.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=2, model__n_estimators=1500, model__subsample=0.3, total=15.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=500, model__subsample=0.3, total= 1.9min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 7.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 7.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 7.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 7.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1000, model__subsample=0.3, total= 7.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=15.2min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=15.2min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=15.2min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=15.2min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=3, model__n_estimators=1500, model__subsample=0.3, total=15.3min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total= 2.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total= 2.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total= 2.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total= 2.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=500, model__subsample=0.3, total= 2.0min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 7.1min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 7.1min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 7.1min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 7.1min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1000, model__subsample=0.3, total= 7.1min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=15.5min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=15.5min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=15.6min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=15.6min
# [CV] model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3
# [CV]  model__booster=dart, model__colsample_bytree=0.6, model__learning_rate=0.1, model__max_depth=4, model__n_estimators=1500, model__subsample=0.3, total=15.5min
# [Parallel(n_jobs=1)]: Done 135 out of 135 | elapsed: 422.9min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           MinMaxScaler()),
#                                                                                          ('power',
#                                                                                           PowerTransformer())]),
#                                                                          Index(['cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7',
#        'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13'],
#       dt...
#                                                      tree_method='gpu_hist',
#                                                      validate_parameters=None,
#                                                      verbosity=None))]),
#              param_grid={'model__booster': ['gbtree', 'gblinear', 'dart'],
#                          'model__colsample_bytree': [0.6],
#                          'model__learning_rate': [0.1],
#                          'model__max_depth': [2, 3, 4],
#                          'model__n_estimators': [500, 1000, 1500],
#                          'model__subsample': [0.3]},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=2)

# %%
print("Best params")
print(search_xgbr.best_params_)
print("\nScore")
print(f'{search_xgbr.best_score_:.4f}')
# Out:
# Best params
# {'model__booster': 'gbtree', 'model__colsample_bytree': 0.6, 'model__learning_rate': 0.1, 'model__max_depth': 2, 'model__n_estimators': 500, 'model__subsample': 0.3}
#
# Score
# -0.5469

# %%
# load test data
X_test = pd.read_csv("../input/30-days-of-ml/test.csv", index_col=0)

# predict
y_pred = search_xgbr.best_estimator_.predict(X_test)
# save the predictions to a CSV file
output = pd.DataFrame({'Id': X_test.index,
                       'target': y_pred})
output.to_csv('submission.csv', index=False)
